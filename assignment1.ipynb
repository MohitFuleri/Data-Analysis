# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'assignment1.ipynb', 'heart_attack_dataset_trimmed.csv']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load dataset
file_path = "heart_attack_dataset_trimmed.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#    Age  Gender  Cholesterol  BloodPressure  HeartRate   BMI  Smoker  Diabetes  \
# 0   31    Male          194            162         71  22.9       0         1
# 1   69    Male          208            148         93  33.9       1         1
# 2   34  Female          132            161         94  34.0       0         0
# 3   53    Male          268            134         91  35.0       0         1
# 4   57  Female          203            140         75  30.1       0         1
#
#    Hypertension  FamilyHistory  ...  ExerciseInducedAngina        Slope  \
# 0             0              0  ...                    Yes  Downsloping
# 1             0              0  ...                    Yes    Upsloping
# 2             1              1  ...                    Yes    Upsloping
# 3             1              0  ...                    Yes         Flat
# 4             0              0  ...                    Yes         Flat
#
#   NumberOfMajorVessels        Thalassemia PreviousHeartAttack  StrokeHistory  \
# 0                    1             Normal                   0              0
# 1                    2             Normal                   0              0
# 2                    0             Normal                   1              0
# 3                    0  Reversible defect                   1              0
# 4                    0       Fixed defect                   1              0
#
#   Residence EmploymentStatus MaritalStatus          Outcome
# 0  Suburban          Retired        Single  No Heart Attack
# 1  Suburban       Unemployed       Married  No Heart Attack
# 2     Rural          Retired        Single     Heart Attack
# 3  Suburban          Retired       Widowed  No Heart Attack
# 4     Rural          Retired       Married     Heart Attack
#
# [5 rows x 32 columns]

# %%
# Univariate Analysis
## Summary statistics for numerical variables
print("\nSummary Statistics:\n", df.describe())
# Out:
# Summary Statistics:
#                  Age    Cholesterol  BloodPressure      HeartRate  \
# count  100000.00000  100000.000000   100000.00000  100000.000000
# mean       57.00714     199.558400      134.58707      89.488900
# std        15.86076      57.820151       25.96612      17.369296
# min        30.00000     100.000000       90.00000      60.000000
# 25%        43.00000     149.000000      112.00000      74.000000
# 50%        57.00000     200.000000      135.00000      89.000000
# 75%        71.00000     250.000000      157.00000     105.000000
# max        84.00000     299.000000      179.00000     119.000000
#
#                  BMI         Smoker       Diabetes   Hypertension  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       28.993863       0.499480       0.500760       0.499600
# std         6.353408       0.500002       0.500002       0.500002
# min        18.000000       0.000000       0.000000       0.000000
# 25%        23.500000       0.000000       0.000000       0.000000
# 50%        29.000000       0.000000       1.000000       0.000000
# 75%        34.500000       1.000000       1.000000       1.000000
# max        40.000000       1.000000       1.000000       1.000000
#
#        FamilyHistory  PhysicalActivity  AlcoholConsumption    StressLevel  \
# count  100000.000000     100000.000000       100000.000000  100000.000000
# mean        0.499390          2.998530            2.000770       5.009640
# std         0.500002          2.000967            1.412944       2.578847
# min         0.000000          0.000000            0.000000       1.000000
# 25%         0.000000          1.000000            1.000000       3.000000
# 50%         0.000000          3.000000            2.000000       5.000000
# 75%         1.000000          5.000000            3.000000       7.000000
# max         1.000000          6.000000            4.000000       9.000000
#
#               Income   MaxHeartRate  ST_Depression  NumberOfMajorVessels  \
# count  100000.000000  100000.000000  100000.000000          100000.00000
# mean   110107.309690     149.417480       2.505416               1.50293
# std     51903.302839      28.835821       1.443169               1.11868
# min     20003.000000     100.000000       0.000000               0.00000
# 25%     65152.750000     124.000000       1.260000               1.00000
# 50%    110096.000000     149.000000       2.500000               2.00000
# 75%    155084.250000     174.000000       3.750000               3.00000
# max    199997.000000     199.000000       5.000000               3.00000
#
#        PreviousHeartAttack  StrokeHistory
# count        100000.000000  100000.000000
# mean              0.497460       0.499480
# std               0.499996       0.500002
# min               0.000000       0.000000
# 25%               0.000000       0.000000
# 50%               0.000000       0.000000
# 75%               1.000000       1.000000
# max               1.000000       1.000000

# %%
## Histograms for numerical variables
plt.figure(figsize=(20, 15))
df.hist(figsize=(20, 15), bins=30, edgecolor='black')
plt.suptitle("Distribution of Numerical Features")
plt.tight_layout()
plt.show()

# %%
## Count plots for categorical variables
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    plt.figure(figsize=(10, 5))
    sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="coolwarm")
    plt.xticks(rotation=45, ha='right')
    plt.title(f"Distribution of {col}")
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\Mohit fuleri\AppData\Local\Temp\ipykernel_31476\2150789202.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="coolwarm")
# C:\Users\Mohit fuleri\AppData\Local\Temp\ipykernel_31476\2150789202.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="coolwarm")
# C:\Users\Mohit fuleri\AppData\Local\Temp\ipykernel_31476\2150789202.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="coolwarm")
# C:\Users\Mohit fuleri\AppData\Local\Temp\ipykernel_31476\2150789202.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="coolwarm")
# C:\Users\Mohit fuleri\AppData\Local\Temp\ipykernel_31476\2150789202.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="coolwarm")
# C:\Users\Mohit fuleri\AppData\Local\Temp\ipykernel_31476\2150789202.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="coolwarm")
# C:\Users\Mohit fuleri\AppData\Local\Temp\ipykernel_31476\2150789202.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="coolwarm")
# C:\Users\Mohit fuleri\AppData\Local\Temp\ipykernel_31476\2150789202.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="coolwarm")
# C:\Users\Mohit fuleri\AppData\Local\Temp\ipykernel_31476\2150789202.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="coolwarm")
# C:\Users\Mohit fuleri\AppData\Local\Temp\ipykernel_31476\2150789202.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="coolwarm")
# C:\Users\Mohit fuleri\AppData\Local\Temp\ipykernel_31476\2150789202.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="coolwarm")
# C:\Users\Mohit fuleri\AppData\Local\Temp\ipykernel_31476\2150789202.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="coolwarm")
# C:\Users\Mohit fuleri\AppData\Local\Temp\ipykernel_31476\2150789202.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="coolwarm")
# C:\Users\Mohit fuleri\AppData\Local\Temp\ipykernel_31476\2150789202.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="coolwarm")

# %%
# Selecting only numerical columns
numeric_df = df.select_dtypes(include=['number'])

# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
## Pairplot for selected variables to check relationships
selected_features = ['Age', 'Cholesterol', 'BloodPressure', 'BMI', 'HeartRate', 'Outcome']
sns.pairplot(df[selected_features], hue='Outcome', palette='husl')
plt.show()

# %%
## Boxplot to analyze distributions by outcome
plt.figure(figsize=(10, 5))
sns.boxplot(x='Outcome', y='Cholesterol', data=df, palette='coolwarm')
plt.title("Cholesterol Levels by Outcome")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Mohit fuleri\AppData\Local\Temp\ipykernel_31476\398819112.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outcome', y='Cholesterol', data=df, palette='coolwarm')

# %%
## Countplot for Gender vs Outcome
plt.figure(figsize=(6, 4))
sns.countplot(x='Gender', hue='Outcome', data=df, palette='coolwarm')
plt.title("Heart Attack Occurrence by Gender")
plt.tight_layout()
plt.show()
